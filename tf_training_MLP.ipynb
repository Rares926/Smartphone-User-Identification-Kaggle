# %%
import tensorflow as tf
import numpy as np 
import pandas as pd 
import os

# %% [markdown]
# Load data method

# %%
def load_labels(data_path: str):
    labels =  pd.read_csv(data_path)
    preproc_labels = labels.values[:,1].reshape(len(labels),1).astype(np.float32) - 1
    return np.array(preproc_labels)

# %%
def load_data_flatten(data_path: str, column_size: int= 150):
    test_data = []
    files = [data_path + file_name for file_name in os.listdir(data_path)]
    all_lenghts = []

    def preproc_input(input):
        input_shape = input.shape
        input =input.T
        tmp_testing_re = []
        for i in range(3):
            if len(input[i]) < column_size:
                    nr_of_0_to_append = column_size - len(input[i])
                    to_append = np.zeros(nr_of_0_to_append)
                    tmp_testing_re.append(np.concatenate((input[i],to_append.astype(np.float32))))
            else:
                tmp_testing_re.append(input[i][0:column_size])

        return np.array(tmp_testing_re).T.flatten()[:column_size*3]

    for file in files: 
        print(file)
        one_input = pd.read_csv(file, header=None, names=['x', 'y', 'z']).values
        print(one_input.shape)
        all_lenghts.append(len(one_input))
        one_input = preproc_input(one_input)
        test_data.append(np.array(one_input))
        # print(np.mean(all_lenghts))
    print(np.mean(all_lenghts))
    return np.array(test_data)

# %%
test_data = load_data_flatten("dataset/test/",156)
# Out:
# dataset/test/10001.csv
# (150, 3)
# dataset/test/10002.csv
# (149, 3)
# dataset/test/10004.csv
# (150, 3)
# dataset/test/10008.csv
# (150, 3)
# dataset/test/10009.csv
# (151, 3)
# dataset/test/10010.csv
# (150, 3)
# dataset/test/10011.csv
# (149, 3)
# dataset/test/10015.csv
# (152, 3)
# dataset/test/10023.csv
# (150, 3)
# dataset/test/10027.csv
# (150, 3)
# dataset/test/10032.csv
# (150, 3)
# dataset/test/10034.csv
# (151, 3)
# dataset/test/10035.csv
# (149, 3)
# dataset/test/10040.csv
# (149, 3)
# dataset/test/10041.csv
# (149, 3)
# dataset/test/10043.csv
# (150, 3)
# dataset/test/10044.csv
# (150, 3)
# dataset/test/10045.csv
# (150, 3)
# dataset/test/10048.csv
# (150, 3)
# dataset/test/10051.csv
# (150, 3)
# dataset/test/10057.csv
# (149, 3)
# dataset/test/10060.csv
# (150, 3)
# dataset/test/10061.csv
# (150, 3)
# dataset/test/10063.csv
# (150, 3)
# dataset/test/10068.csv
# (151, 3)
# dataset/test/10069.csv
# (150, 3)
# dataset/test/10073.csv
# (150, 3)
# dataset/test/10080.csv
# ...

# %%
train_data = load_data_flatten("dataset/train/",156)
# Out:
# dataset/train/10003.csv
# (150, 3)
# dataset/train/10005.csv
# (149, 3)
# dataset/train/10006.csv
# (150, 3)
# dataset/train/10007.csv
# (150, 3)
# dataset/train/10012.csv
# (150, 3)
# dataset/train/10013.csv
# (149, 3)
# dataset/train/10014.csv
# (150, 3)
# dataset/train/10016.csv
# (151, 3)
# dataset/train/10017.csv
# (150, 3)
# dataset/train/10018.csv
# (150, 3)
# dataset/train/10019.csv
# (149, 3)
# dataset/train/10020.csv
# (149, 3)
# dataset/train/10021.csv
# (150, 3)
# dataset/train/10022.csv
# (150, 3)
# dataset/train/10024.csv
# (150, 3)
# dataset/train/10025.csv
# (150, 3)
# dataset/train/10026.csv
# (149, 3)
# dataset/train/10028.csv
# (150, 3)
# dataset/train/10029.csv
# (150, 3)
# dataset/train/10030.csv
# (150, 3)
# dataset/train/10031.csv
# (151, 3)
# dataset/train/10033.csv
# (150, 3)
# dataset/train/10036.csv
# (150, 3)
# dataset/train/10037.csv
# (150, 3)
# dataset/train/10038.csv
# (150, 3)
# dataset/train/10039.csv
# (150, 3)
# dataset/train/10042.csv
# (149, 3)
# ...

# %%
print(f"Test data shape -->{test_data.shape}")
print(f"Train data shape-->{train_data.shape}")
# Out:
# Test data shape -->(5000, 468)
# Train data shape-->(9000, 468)

# %%
len(test_data[1])
# Out:
# 468

# %%
train_labels = load_labels("dataset/train_labels.csv")
train_labels.shape
# Out:
# (9000, 1)

# %% [markdown]
# Create model

# %%
# 0.76
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(512, activation='relu'), 
  tf.keras.layers.Dense(512, activation='relu'), 
  tf.keras.layers.Dropout(0.2), 
  tf.keras.layers.Dense(1024, activation='relu'), 
  tf.keras.layers.Dense(1024, activation='relu'), 
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(20, activation='softmax') 
])

# %%
# this only for the model next to this box
train_data = train_data[:,:,np.newaxis]
test_data = test_data[:,:,np.newaxis]

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5, activation='relu'),
  tf.keras.layers.MaxPooling1D(pool_size=2),
  tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling1D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(20, activation='softmax')
])

# %%
# https://www.researchgate.net/profile/Sarbagya-Shakya/publication/328725395_Comparative_Study_of_Machine_Learning_and_Deep_Learning_Architecture_for_Human_Activity_Recognition_Using_Accelerometer_Data/links/5c89557092851c1df93ff1ef/Comparative-Study-of-Machine-Learning-and-Deep-Learning-Architecture-for-Human-Activity-Recognition-Using-Accelerometer-Data.pdf
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=(2,2), padding='same'),
  tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=(2,2), padding='same'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=(2,2), padding='same'),
  tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2, strides=(2,2), padding='same'),
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(20, activation='softmax')
])

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop 

# define the optimizer, set the learning rate and the momentum (for SGD with momentum)
optimizer = SGD(learning_rate=0.001, momentum=0.9)  
# compile the model specifying the optimizer, the loss and the metrics (as an array).
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train Model

# %%
model.fit(train_data[:-1000], train_labels[:-1000],
          epochs=100, batch_size=32, initial_epoch=0,
          validation_data=(train_data[-1000:], train_labels[-1000:]))
# Out:
# Epoch 1/100
# 250/250 [==============================] - 57s 76ms/step - loss: 2.7614 - accuracy: 0.1332 - val_loss: 2.3526 - val_accuracy: 0.2550
# Epoch 2/100
# 250/250 [==============================] - 3s 11ms/step - loss: 2.3226 - accuracy: 0.2261 - val_loss: 2.0466 - val_accuracy: 0.3190
# Epoch 3/100
# 250/250 [==============================] - 3s 11ms/step - loss: 2.0769 - accuracy: 0.2884 - val_loss: 1.9098 - val_accuracy: 0.3340
# Epoch 4/100
# 250/250 [==============================] - 2s 10ms/step - loss: 1.9539 - accuracy: 0.3240 - val_loss: 1.7747 - val_accuracy: 0.4010
# Epoch 5/100
# 250/250 [==============================] - 2s 10ms/step - loss: 1.8742 - accuracy: 0.3581 - val_loss: 1.7377 - val_accuracy: 0.4160
# Epoch 6/100
# 250/250 [==============================] - 2s 10ms/step - loss: 1.7936 - accuracy: 0.3783 - val_loss: 1.6580 - val_accuracy: 0.4480
# Epoch 7/100
# ...
